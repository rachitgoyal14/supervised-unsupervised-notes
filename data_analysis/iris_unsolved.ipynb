# %% [markdown]
# #### __Download iris dataset from https://archive.ics.uci.edu/ml/datasets/iris__
# #### __Create a copy of the file iris.data and replace__
# #### __Iris-setosa with Iris-setosa,1__
# #### __Iris-versicolor with Iris-versicolor,2__
# #### __Iris-virginica with Iris-virginica,3__
# #### __"save" this file__

# %%
import numpy as np
help(np.genfromtxt)
# Out:
# Help on function genfromtxt in module numpy:
#
# genfromtxt(fname, dtype=<class 'float'>, comments='#', delimiter=None, skip_header=0, skip_footer=0, converters=None, missing_values=None, filling_values=None, usecols=None, names=None, excludelist=None, deletechars=" !#$%&'()*+,-./:;<=>?@[\\]^{|}~", replace_space='_', autostrip=False, case_sensitive=True, defaultfmt='f%i', unpack=None, usemask=False, loose=True, invalid_raise=True, max_rows=None, encoding=None, *, ndmin=0, like=None)
#     Load data from a text file, with missing values handled as specified.
#
#     Each line past the first `skip_header` lines is split at the `delimiter`
#     character, and characters following the `comments` character are discarded.
#
#     Parameters
#     ----------
#     fname : file, str, pathlib.Path, list of str, generator
#         File, filename, list, or generator to read.  If the filename
#         extension is ``.gz`` or ``.bz2``, the file is first decompressed. Note
# ...

# %% [markdown]
# #### __Load the data in the file Iris.txt in a 2-D array called iris.__

# %%
iris = np.genfromtxt(
    "iris/iris.data",
    delimiter=",",
    dtype=float,
    encoding="utf-8"
)
print(iris)
# Out:
# [[5.1 3.5 1.4 0.2 1. ]
#  [4.9 3.  1.4 0.2 1. ]
#  [4.7 3.2 1.3 0.2 1. ]
#  [4.6 3.1 1.5 0.2 1. ]
#  [5.  3.6 1.4 0.2 1. ]
#  [5.4 3.9 1.7 0.4 1. ]
#  [4.6 3.4 1.4 0.3 1. ]
#  [5.  3.4 1.5 0.2 1. ]
#  [4.4 2.9 1.4 0.2 1. ]
#  [4.9 3.1 1.5 0.1 1. ]
#  [5.4 3.7 1.5 0.2 1. ]
#  [4.8 3.4 1.6 0.2 1. ]
#  [4.8 3.  1.4 0.1 1. ]
#  [4.3 3.  1.1 0.1 1. ]
#  [5.8 4.  1.2 0.2 1. ]
#  [5.7 4.4 1.5 0.4 1. ]
#  [5.4 3.9 1.3 0.4 1. ]
#  [5.1 3.5 1.4 0.3 1. ]
#  [5.7 3.8 1.7 0.3 1. ]
#  [5.1 3.8 1.5 0.3 1. ]
#  [5.4 3.4 1.7 0.2 1. ]
#  [5.1 3.7 1.5 0.4 1. ]
#  [4.6 3.6 1.  0.2 1. ]
#  [5.1 3.3 1.7 0.5 1. ]
#  [4.8 3.4 1.9 0.2 1. ]
#  [5.  3.  1.6 0.2 1. ]
#  [5.  3.4 1.6 0.4 1. ]
#  [5.2 3.5 1.5 0.2 1. ]
#  [5.2 3.4 1.4 0.2 1. ]
#  [4.7 3.2 1.6 0.2 1. ]
#  [4.8 3.1 1.6 0.2 1. ]
#  [5.4 3.4 1.5 0.4 1. ]
#  [5.2 4.1 1.5 0.1 1. ]
#  [5.5 4.2 1.4 0.2 1. ]
#  [4.9 3.1 1.5 0.1 1. ]
#  [5.  3.2 1.2 0.2 1. ]
#  [5.5 3.5 1.3 0.2 1. ]
#  [4.9 3.1 1.5 0.1 1. ]
#  [4.4 3.  1.3 0.2 1. ]
#  [5.1 3.4 1.5 0.2 1. ]
# ...

# %% [markdown]
# #### __Drop column whose index = 4 from the array iris.__

# %% [markdown]
# #### __Display the shape, dimensions and size of iris.__

# %%
print(iris.shape)
print(iris.size)
print(iris.ndim)
# Out:
# (150, 5)
# 750
# 2

# %% [markdown]
# #### __Split iris into three 2-D arrays, each array for a different species. Call them iris1, iris2, iris3.__

# %%
iris1, iris2, iris3 = np.split(iris, [49, 99])
print(iris1)
print(iris2)
print(iris3)
# Out:
# [[5.1 3.5 1.4 0.2 1. ]
#  [4.9 3.  1.4 0.2 1. ]
#  [4.7 3.2 1.3 0.2 1. ]
#  [4.6 3.1 1.5 0.2 1. ]
#  [5.  3.6 1.4 0.2 1. ]
#  [5.4 3.9 1.7 0.4 1. ]
#  [4.6 3.4 1.4 0.3 1. ]
#  [5.  3.4 1.5 0.2 1. ]
#  [4.4 2.9 1.4 0.2 1. ]
#  [4.9 3.1 1.5 0.1 1. ]
#  [5.4 3.7 1.5 0.2 1. ]
#  [4.8 3.4 1.6 0.2 1. ]
#  [4.8 3.  1.4 0.1 1. ]
#  [4.3 3.  1.1 0.1 1. ]
#  [5.8 4.  1.2 0.2 1. ]
#  [5.7 4.4 1.5 0.4 1. ]
#  [5.4 3.9 1.3 0.4 1. ]
#  [5.1 3.5 1.4 0.3 1. ]
#  [5.7 3.8 1.7 0.3 1. ]
#  [5.1 3.8 1.5 0.3 1. ]
#  [5.4 3.4 1.7 0.2 1. ]
#  [5.1 3.7 1.5 0.4 1. ]
#  [4.6 3.6 1.  0.2 1. ]
#  [5.1 3.3 1.7 0.5 1. ]
#  [4.8 3.4 1.9 0.2 1. ]
#  [5.  3.  1.6 0.2 1. ]
#  [5.  3.4 1.6 0.4 1. ]
#  [5.2 3.5 1.5 0.2 1. ]
#  [5.2 3.4 1.4 0.2 1. ]
#  [4.7 3.2 1.6 0.2 1. ]
#  [4.8 3.1 1.6 0.2 1. ]
#  [5.4 3.4 1.5 0.4 1. ]
#  [5.2 4.1 1.5 0.1 1. ]
#  [5.5 4.2 1.4 0.2 1. ]
#  [4.9 3.1 1.5 0.1 1. ]
#  [5.  3.2 1.2 0.2 1. ]
#  [5.5 3.5 1.3 0.2 1. ]
#  [4.9 3.1 1.5 0.1 1. ]
#  [4.4 3.  1.3 0.2 1. ]
#  [5.1 3.4 1.5 0.2 1. ]
# ...

# %% [markdown]
# #### __Print the three arrays iris1, iris2, iris3__

# %%
print(iris1)
print(iris2)
print(iris3)
# Out:
# [[5.1 3.5 1.4 0.2 1. ]
#  [4.9 3.  1.4 0.2 1. ]
#  [4.7 3.2 1.3 0.2 1. ]
#  [4.6 3.1 1.5 0.2 1. ]
#  [5.  3.6 1.4 0.2 1. ]
#  [5.4 3.9 1.7 0.4 1. ]
#  [4.6 3.4 1.4 0.3 1. ]
#  [5.  3.4 1.5 0.2 1. ]
#  [4.4 2.9 1.4 0.2 1. ]
#  [4.9 3.1 1.5 0.1 1. ]
#  [5.4 3.7 1.5 0.2 1. ]
#  [4.8 3.4 1.6 0.2 1. ]
#  [4.8 3.  1.4 0.1 1. ]
#  [4.3 3.  1.1 0.1 1. ]
#  [5.8 4.  1.2 0.2 1. ]
#  [5.7 4.4 1.5 0.4 1. ]
#  [5.4 3.9 1.3 0.4 1. ]
#  [5.1 3.5 1.4 0.3 1. ]
#  [5.7 3.8 1.7 0.3 1. ]
#  [5.1 3.8 1.5 0.3 1. ]
#  [5.4 3.4 1.7 0.2 1. ]
#  [5.1 3.7 1.5 0.4 1. ]
#  [4.6 3.6 1.  0.2 1. ]
#  [5.1 3.3 1.7 0.5 1. ]
#  [4.8 3.4 1.9 0.2 1. ]
#  [5.  3.  1.6 0.2 1. ]
#  [5.  3.4 1.6 0.4 1. ]
#  [5.2 3.5 1.5 0.2 1. ]
#  [5.2 3.4 1.4 0.2 1. ]
#  [4.7 3.2 1.6 0.2 1. ]
#  [4.8 3.1 1.6 0.2 1. ]
#  [5.4 3.4 1.5 0.4 1. ]
#  [5.2 4.1 1.5 0.1 1. ]
#  [5.5 4.2 1.4 0.2 1. ]
#  [4.9 3.1 1.5 0.1 1. ]
#  [5.  3.2 1.2 0.2 1. ]
#  [5.5 3.5 1.3 0.2 1. ]
#  [4.9 3.1 1.5 0.1 1. ]
#  [4.4 3.  1.3 0.2 1. ]
#  [5.1 3.4 1.5 0.2 1. ]
# ...

# %% [markdown]
# #### __Find the max, min, mean and standard deviation for the columns of the iris and store the results in the arrays iris_max, iris_min, iris_avg, iris_std, iris_ var respectively. The results must be rounded to not more than two decimal places.__

# %%
iris_max = iris.max(axis = 0)
iris_min = iris.min(axis = 0)
iris_avg = iris.mean(axis = 0)
iris_std = iris.std(axis=0)
iris_var = iris.var(axis=0)

print(iris_max)
print(iris_avg)
# Out:
# [7.9 4.4 6.9 2.5 3. ]
# [5.84333333 3.054      3.75866667 1.19866667 2.        ]

# %% [markdown]
# #### __Similarly find the max, min, mean and standard deviation for the columns of the iris1, iris2 and iris3 and store the results in the arrays with appropriate names__

# %%
iris_max1 = iris1.max(axis=0)
iris_min1 = iris1.min(axis=0)
iris_avg1 = iris1.mean(axis=0)
iris_std1 = iris1.std(axis=0)
print(iris_max1)

iris_max2 = iris2.max(axis=0)
iris_min2 = iris2.min(axis=0)
iris_avg2 = iris2.mean(axis=0)
iris_std2 = iris2.std(axis=0)
print(iris_max2)

iris_max3 = iris3.max(axis=0)
iris_min3 = iris3.min(axis=0)
iris_avg3 = iris3.mean(axis=0)
iris_std3 = iris3.std(axis=0)
print(iris_max3)
# Out:
# [5.8 4.4 1.9 0.6 1. ]
# [7.  3.4 5.1 1.8 2. ]
# [7.9 3.8 6.9 2.5 3. ]

# %% [markdown]
# #### __Check the minimum value for sepal length, sepal width, petal length and petal width of the three species in comparison to the minimum value of sepal length, sepal width, petal length and petal width for the data set as a whole and fill the table with True if the species value is greater than the dataset value and False otherwise. The table should have columns Iris setosa, Iris virginica, Iris versicolor and rows are sepal length, sepal width, petal length and petal width__

# %% [markdown]
# #### __Compare Iris setosa’s average sepal width to that of Iris virginica.__

# %% [markdown]
# #### __Compare Iris setosa’s average petal length to that of Iris virginica.__

# %% [markdown]
# #### __Compare Iris setosa’s average petal width to that of Iris virginica.__

# %% [markdown]
# #### __Save the array iris_avg in a comma separated file named IrisMeanValues.txt on the hard disk.__

# %% [markdown]
# #### __Save the arrays iris_max, iris_avg, iris_min in a comma separated file named IrisStat.txt on the hard disk__
