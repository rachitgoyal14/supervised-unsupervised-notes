# %% [markdown]
# ## __1. Activity on CCA__
#
# ```
# import pandas as pd
# df = pd.DataFrame(
#   {
#     "Employee_Name": ["Rohit", "Sneha", "Karan", "Meena", "Vikas", "Pooja", "Arjun", "Neha"],
#     "Experience_Years": [2, 5, None, 7, 3, None, 10, 4],
#     "Monthly_Salary": [25000, 42000, 38000, None, 30000, 28000, 60000, None]
#   }
# )
#
# print("Original Dataframe")
# print(df)
# original_rows = df.shape[0]
# print("Original Rows:", original_rows)
# ```
#
# #### A. Print Missing Values in Each Column.
# #### B. Apply CCA on the same
# #### C. Display number of rows remained after the data CCA
# #### D. Display number of rows eliminated after the data CCA
# #### E. Display the % of rows eliminated after CCA

# %% [markdown]
# ## __2. Activity on Mean, Median and End of Distribution Imputation__
#
# ```
# import pandas as pd
# import numpy as np
# df = pd.DataFrame(
#   {
#     "House_ID": [101,102,103,104,105,106,107,108],
#     "House_Size_sqft": [1200, 1500, np.nan, 1800, 2000, np.nan, 2200, 5000],  # 5000 is outlier
#     "Price_Lakhs": [60, 75, 70, np.nan, 95, 90, 110, np.nan]
#   }
# )
# print("Original Dataset:\n")
# print(df)
# ```
#
# #### A. Identify missing values in each column.
# #### B. Apply Mean Imputation to numerical columns(House_Size_sqft,Price_Lakhs).
# #### C. Apply Median Imputation.
# #### D. Apply End-of-Distribution Imputation (Mean + 3 × Std).
# #### E. Compare imputed values for missing entries.

# %%
#Write your solution here

# %% [markdown]
# ## __3. Activity on Mode Imputation, Arbitrary Value Imputation and MissingIndicator__
# ````
# import pandas as pd
# import numpy as np
# df = pd.DataFrame(
#   {
#     "Employee_ID": [201,202,203,204,205,206,207,208],
#     "Department": ["HR", "IT", np.nan, "Finance", "IT", np.nan, "HR", "Finance"],
#     "Work_Mode": ["Office", np.nan, "Remote", "Office", "Remote", "Remote", np.nan, "Office"],
#     "Years_at_Company": [2, 5, 3, np.nan, 4, 6, np.nan, 1]
#   }
# )
# print("Original Dataset:\n")
# print(df)
# ````
# #### A. Identify missing values in each column.
# #### B.  Apply Mode Imputation to categorical columns.
# #### C.  Apply Arbitrary Value Imputation: Replace missing categorical values with "UNKNOWN"; Numerical values with −1
# #### D. Generate missing-value indicator features using MissingIndicator.
# #### E. Combine original data, imputed data, and indicators.

# %%
#write your solution here

# %% [markdown]
# ## __4. Activity on KNNImputor__
#
# __Compute nan-euclidean distances for observations with missing values, identify k-nearest neighbors (k = 2), estimate missing values, and verify results using KNN Imputer in Scikit-Learn.__
# ````
# import pandas as pd
# df = pd.DataFrame(
#   {
#     "Temperature": {10, 14, np.nan, 22},
#     "Vibration": {20, 24, 28, 32},
#     "Pressure": {np.nan, 30, 34, 38}
#   }
# )
# ````
#
# #### A. Compute nan-euclidean distance from Row-0 to all other rows.
# #### B. Compute nan-euclidean distance from Row-2 to all other rows.
# #### C. Choose k = 2 nearest neighbors.
# #### D. Estimate missing values using neighbor averages(uniform weight).
# #### E. Assigned weight according to the distance and impute missing value.

# %%
#write your solution here

# %% [markdown]
# ## __5. Activity on Random Value Imputation__
# ````
# import pandas as pd
# import numpy as np
# df = pd.DataFrame({
#     "Orders_Per_Day": [120, 150, np.nan, 180, 200, np.nan, 170, 160, np.nan]
# })
# print("Original Dataset:")
# print(df)
# ````
#
# #### A. Extract all non-missing order counts.
# #### B. Randomly sample values equal to the number of missing entries.
# #### C. Replace NaN values with sampled values.
# #### D. Compare original vs imputed dataset.

# %%
#write your solution here
